# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail(4)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# ...

# %%
df.sort_values(['DailyRate'], ascending = 1)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 649    53        No      Travel_Rarely        102  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 1110   35       Yes      Travel_Rarely        104  Research & Development
# 1437   39        No         Non-Travel        105  Research & Development
# 310    31        No      Travel_Rarely        106         Human Resources
# ...   ...       ...                ...        ...                     ...
# 1202   38        No      Travel_Rarely       1495  Research & Development
# 155    29        No         Non-Travel       1496  Research & Development
# 1056   28       Yes  Travel_Frequently       1496                   Sales
# 986    39        No      Travel_Rarely       1498                   Sales
# 427    60        No  Travel_Frequently       1499                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df2 = df.sort_values(['DistanceFromHome'], ascending = 0)
df2
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 352    48        No      Travel_Rarely        530                   Sales
# 875    44        No      Travel_Rarely        200  Research & Development
# 792    33       Yes  Travel_Frequently        827  Research & Development
# 1434   52        No         Non-Travel        585                   Sales
# 1109   30        No      Travel_Rarely       1288                   Sales
# ...   ...       ...                ...        ...                     ...
# 1121   36        No      Travel_Rarely        884                   Sales
# 1117   34        No      Travel_Rarely       1351  Research & Development
# 414    24       Yes      Travel_Rarely       1448                   Sales
# 1113   32        No         Non-Travel       1200  Research & Development
# 0      41       Yes      Travel_Rarely       1102                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df_obj = df.select_dtypes(['object'])
df_obj
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
df_int = df.select_dtypes(['int64'])
df_int
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['EducationField'].nunique()
# Out:
# 6

# %%
for column in df:
    print("column"," ", column, "uniquevalues are :", df[column].nunique())
# Out:
# column   Age uniquevalues are : 43
# column   Attrition uniquevalues are : 2
# column   BusinessTravel uniquevalues are : 3
# column   DailyRate uniquevalues are : 886
# column   Department uniquevalues are : 3
# column   DistanceFromHome uniquevalues are : 29
# column   Education uniquevalues are : 5
# column   EducationField uniquevalues are : 6
# column   EmployeeCount uniquevalues are : 1
# column   EmployeeNumber uniquevalues are : 1470
# column   EnvironmentSatisfaction uniquevalues are : 4
# column   Gender uniquevalues are : 2
# column   HourlyRate uniquevalues are : 71
# column   JobInvolvement uniquevalues are : 4
# column   JobLevel uniquevalues are : 5
# column   JobRole uniquevalues are : 9
# column   JobSatisfaction uniquevalues are : 4
# column   MaritalStatus uniquevalues are : 3
# column   MonthlyIncome uniquevalues are : 1349
# column   MonthlyRate uniquevalues are : 1427
# column   NumCompaniesWorked uniquevalues are : 10
# column   Over18 uniquevalues are : 1
# ...

# %%
df['WorkLifeBalance'].value_counts()
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df['WorkLifeBalance'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: WorkLifeBalance, Length: 1470, dtype: bool

# %%
df['WorkLifeBalance'].isnull().sum()
# Out:
# 0

# %%
for column in df.columns:
    null_count = df[column].isnull().sum()
    print(f"Column '{column}' has {null_count} null values.")
# Out:
# Column 'Age' has 0 null values.
# Column 'Attrition' has 0 null values.
# Column 'BusinessTravel' has 0 null values.
# Column 'DailyRate' has 0 null values.
# Column 'Department' has 0 null values.
# Column 'DistanceFromHome' has 0 null values.
# Column 'Education' has 0 null values.
# Column 'EducationField' has 0 null values.
# Column 'EmployeeCount' has 0 null values.
# Column 'EmployeeNumber' has 0 null values.
# Column 'EnvironmentSatisfaction' has 0 null values.
# Column 'Gender' has 0 null values.
# Column 'HourlyRate' has 0 null values.
# Column 'JobInvolvement' has 0 null values.
# Column 'JobLevel' has 0 null values.
# Column 'JobRole' has 0 null values.
# Column 'JobSatisfaction' has 0 null values.
# Column 'MaritalStatus' has 0 null values.
# Column 'MonthlyIncome' has 0 null values.
# Column 'MonthlyRate' has 0 null values.
# Column 'NumCompaniesWorked' has 0 null values.
# Column 'Over18' has 0 null values.
# Column 'OverTime' has 0 null values.
# ...

# %%
df.loc[(df.Department == 'Research & Development') & (df.Education == 2)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# 13     34        No      Travel_Rarely       1346  Research & Development
# 16     32        No      Travel_Rarely        334  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1425   33        No      Travel_Rarely        501  Research & Development
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.loc[(df.EducationField.isin(['Medical', 'Life Sciences']))]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df["current status"]= 'employed'
df["current status"]
# Out:
# 0       employed
# 1       employed
# 2       employed
# 3       employed
# 4       employed
#           ...
# 1465    employed
# 1466    employed
# 1467    employed
# 1468    employed
# 1469    employed
# Name: current status, Length: 1470, dtype: object

# %%
df[df['Attrition']=='Yes']
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
#mean of all columns
df.groupby(['WorkLifeBalance']).mean(numeric_only=True)
# Out:
#                        Age   DailyRate  DistanceFromHome  Education  \
# WorkLifeBalance
# 1                37.287500  812.100000          9.425000   2.975000
# 2                37.188953  827.459302          9.325581   2.857558
# 3                36.849944  798.409854          9.277716   2.927212
# 4                36.568627  765.098039          8.274510   2.921569
#
#                  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# WorkLifeBalance
# 1                          1.0     1014.237500                 2.650000
# 2                          1.0     1026.511628                 2.671512
# 3                          1.0     1019.240761                 2.744681
# 4                          1.0     1059.549020                 2.738562
#
#                  HourlyRate  JobInvolvement  JobLevel  ...  PerformanceRating  \
# WorkLifeBalance                                        ...
# 1                 63.800000        2.737500  1.875000  ...           3.175000
# ...

# %%
# mean of only specific column
df.groupby(['WorkLifeBalance'])['HourlyRate'].mean()

# %%
dfgf=pd.DataFrame(df.groupby(['JobRole']).agg({'Age':[np.mean,np.std],'HourlyRate':[np.mean,'count'],'Education':'nunique'}))
dfgf
# Out:
# C:\Users\Asia0\AppData\Local\Temp\ipykernel_22632\518639123.py:1: FutureWarning: The provided callable <function mean at 0x00000222B00B4900> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   dfgf=pd.DataFrame(df.groupby(['JobRole']).agg({'Age':[np.mean,np.std],'HourlyRate':[np.mean,'count'],'Education':'nunique'}))
# C:\Users\Asia0\AppData\Local\Temp\ipykernel_22632\518639123.py:1: FutureWarning: The provided callable <function std at 0x00000222B00B4A40> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   dfgf=pd.DataFrame(df.groupby(['JobRole']).agg({'Age':[np.mean,np.std],'HourlyRate':[np.mean,'count'],'Education':'nunique'}))
# ...
